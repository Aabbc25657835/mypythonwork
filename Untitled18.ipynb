# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print('單純射飛鏢 好玩而已')
a=0
r=1
x = np.arange(-100, 100, 0.0001)
y = np.sqrt(100**2 - x**2)
plt.plot(x, y,color='black')
plt.plot(x,-y,color='black')
x = np.arange(-200, 200, 0.0001)
y = np.sqrt(200**2 - x**2)
plt.plot(x, y,color='black')
plt.plot(x,-y,color='black')
x = np.arange(-300, 300, 0.0001)
y = np.sqrt(300**2 - x**2)
plt.plot(x, y,color='black')
plt.plot(x,-y,color='black')
plt.axis('equal')

x=randint(-300,300)
y=randint(-300,300)
plt.scatter(x,y)
# Out:
# 單純射飛鏢 好玩而已
